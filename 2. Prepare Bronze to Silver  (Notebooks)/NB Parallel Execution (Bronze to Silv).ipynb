# %% [markdown]
# https://learn.microsoft.com/en-us/fabric/data-engineering/notebook-utilities

# %%
# Execute multiple notebooks in parallel
# Optimize the use of Spark compute resources and reduce the cost

from notebookutils import notebook as nb

nb.runMultiple(["game_goals: bronze_to_silv (Jack)", 
                "game_goalie_stats: bronze_to_silv (Jack)",
                "game_officials: bronze_to_silv (Jack)",
                "game_penalties: bronze_to_silv (Jack)",
                "game_scratches: bronze_to_silv (Swathi)",
                "game_shifts: bronze_to_silv (Swathi)",
                "game_skater_stats: bronze_to_silv (Najihah)",
                "game_teams_stats: bronze_to_silv (Najihah)",
                "games: bronze_to_silv (Jack)",
                "games_plays: bronze_to_silv (Swathi)",
                "games_plays_players: bronze_to_silv (Swathi)",
                "player_info: bronze_to_silv (Najihah)",
                "team_info: bronze_to_silv (Najihah)"
                ])
# Out:
# StatementMeta(, abd4f997-c19a-4dff-b2a8-8aa88a361f3c, 4, Finished, Available, Finished)
# {'0': {'exitVal': '', 'exception': None},
#  '1': {'exitVal': '', 'exception': None},
#  '2': {'exitVal': '', 'exception': None},
#  '3': {'exitVal': '', 'exception': None},
#  '4': {'exitVal': '', 'exception': None},
#  '5': {'exitVal': '', 'exception': None},
#  '6': {'exitVal': '', 'exception': None},
#  '7': {'exitVal': '', 'exception': None},
#  '8': {'exitVal': '', 'exception': None},
#  '9': {'exitVal': '', 'exception': None},
#  '10': {'exitVal': '', 'exception': None},
#  '11': {'exitVal': '', 'exception': None},
#  '12': {'exitVal': '', 'exception': None}}
